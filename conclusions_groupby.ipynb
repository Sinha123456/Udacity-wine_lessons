# %% [markdown]
# # Drawing Conclusions Using Groupby

# %% [markdown]
# Use `winequality_edited.csv`. You should've created this data file in the previous section: *Appending Data (cont.)*.

# %%
# Load dataset
import pandas as pd
import numpy as np

df = pd.read_csv('winequality_edited.csv')
df.head(5)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red           High
# 1      9.8        5   red           High
# 2      9.8        5   red           High
# 3      9.8        6   red           High
# 4      9.4        5   red           High

# %% [markdown]
# ### Is a certain type of wine associated with higher quality?

# %%
# Find the mean quality of each wine type (red and white) with groupby
df.groupby(['quality', 'color']).mean()
# Out:
#                fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality color
# 3       red         8.360000          0.884500     0.171000        2.635000
#         white       7.600000          0.333250     0.336000        6.392500
# 4       red         7.779245          0.693962     0.174151        2.694340
#         white       7.129448          0.381227     0.304233        4.628221
# 5       red         8.167254          0.577041     0.243686        2.528855
#         white       6.933974          0.302011     0.337653        7.334969
# 6       red         8.347179          0.497484     0.273824        2.477194
#         white       6.837671          0.260564     0.338025        6.441606
# 7       red         8.872362          0.403920     0.375176        2.720603
#         white       6.734716          0.262767     0.325625        5.186477
# 8       red         8.566667          0.423333     0.391111        2.577778
#         white       6.657143          0.277400     0.326514        5.671429
# 9       white       7.420000          0.298000     0.386000        4.120000
#
#                chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# quality color
# 3       red     0.122500            11.000000             24.900000  0.997464
#         white   0.054300            53.325000            170.600000  0.994884
# 4       red     0.090679            12.264151             36.245283  0.996542
#         white   0.050098            23.358896            125.279141  0.994277
# 5       red     0.092736            16.983847             56.513950  0.997104
#         white   0.051546            36.432052            150.904598  0.995263
# 6       red     0.084956            15.711599             40.869906  0.996615
#         white   0.045217            35.650591            137.047316  0.993961
# 7       red     0.076588            14.045226             35.020101  0.996104
#         white   0.038191            34.125568            125.114773  0.992452
# 8       red     0.068444            13.277778             33.444444  0.995212
#         white   0.038314            36.720000            126.165714  0.992236
# 9       white   0.027400            33.400000            116.000000  0.991460
#
#                      pH  sulphates    alcohol
# quality color
# 3       red    3.398000   0.570000   9.955000
#         white  3.187500   0.474500  10.345000
# 4       red    3.381509   0.596415  10.265094
#         white  3.182883   0.476135  10.152454
# 5       red    3.304949   0.620969   9.899706
#         white  3.168833   0.482203   9.808840
# 6       red    3.318072   0.675329  10.629519
#         white  3.188599   0.491106  10.575372
# 7       red    3.290754   0.741256  11.465913
#         white  3.213898   0.503102  11.367936
# 8       red    3.267222   0.767778  12.094444
#         white  3.218686   0.486229  11.636000
# 9       white  3.308000   0.466000  12.180000

# %%
df['pH'].min()
# Out:
# 2.7200000000000002

# %%
df['pH'].max()
# Out:
# 4.0099999999999998

# %%
df['pH'].tolist()
# Out:
# [3.51,
#  3.2,
#  3.26,
#  3.16,
#  3.51,
#  3.51,
#  3.3,
#  3.39,
#  3.36,
#  3.35,
#  3.28,
#  3.35,
#  3.58,
#  3.26,
#  3.16,
#  3.17,
#  3.3,
#  3.11,
#  3.38,
#  3.04,
#  3.39,
#  3.52,
#  3.17,
#  3.17,
#  3.43,
#  3.34,
#  3.28,
#  3.17,
#  3.47,
#  3.38,
#  3.35,
#  3.46,
#  3.17,
#  3.45,
#  3.38,
#  3.4,
#  3.42,
#  3.23,
#  3.5,
#  3.33,
#  3.33,
#  3.26,
#  3.21,
#  3.3,
#  3.48,
#  3.9,
#  3.25,
#  3.25,
#  3.34,
#  3.32,
#  3.15,
#  3.4,
#  3.39,
#  3.2,
#  3.17,
#  3.34,
#  3.04,
#  3.26,
#  3.43,
#  3.41,
#  3.44,
#  3.21,
#  3.38,
#  3.39,
#  3.41,
#  3.41,
#  3.42,
#  3.44,
#  3.28,
#  3.34,
#  3.32,
#  3.32,
#  3.31,
#  3.31,
#  3.28,
#  3.54,
#  3.54,
#  3.52,
#  3.38,
#  3.16,
#  3.41,
#  3.13,
#  3.36,
#  3.16,
#  3.44,
#  3.41,
#  2.93,
#  3.39,
#  3.14,
#  3.48,
#  3.23,
#  2.93,
#  2.93,
#  3.39,
#  3.75,
#  3.85,
#  3.45,
#  3.25,
#  3.39,
#  3.3,
#  3.4,
#  3.31,
#  3.3,
#  3.29,
#  3.33,
#  3.29,
#  3.08,
#  3.46,
#  3.37,
#  3.21,
#  3.19,
#  3.15,
#  3.15,
#  3.32,
#  3.19,
#  3.07,
#  3.39,
#  3.37,
#  3.21,
#  3.34,
#  3.3,
#  3.21,
#  3.49,
#  3.44,
#  3.39,
#  3.16,
#  3.53,
#  3.54,
#  3.42,
#  3.42,
#  3.24,
#  3.63,
#  3.63,
#  3.4,
#  3.22,
#  3.19,
#  3.23,
#  3.48,
#  3.33,
#  3.32,
#  3.19,
#  3.23,
#  3.68,
#  3.34,
#  3.68,
#  3.17,
#  3.54,
#  3.11,
#  3.42,
#  3.53,
#  3.33,
#  2.74,
#  3.35,
#  3.35,
#  3.42,
#  3.42,
#  3.42,
#  3.42,
#  3.48,
#  3.59,
#  3.2,
#  3.17,
#  3.33,
#  3.37,
#  3.37,
#  3.19,
#  3.34,
#  3.37,
#  3.47,
#  3.0,
#  3.36,
#  3.29,
#  3.29,
#  3.42,
#  3.33,
#  3.35,
#  3.33,
#  3.58,
#  3.48,
#  3.19,
#  3.19,
#  3.12,
#  3.44,
#  3.54,
#  3.52,
#  3.26,
#  3.34,
#  3.39,
#  3.2,
#  3.2,
#  3.23,
#  3.57,
#  3.28,
#  3.28,
#  3.28,
#  3.25,
#  3.46,
#  3.11,
#  3.57,
#  3.51,
#  3.22,
#  3.04,
#  3.36,
#  3.34,
#  3.34,
#  3.2,
#  3.2,
#  3.29,
#  3.22,
#  3.31,
#  3.3,
#  3.35,
#  3.21,
#  3.3,
#  3.24,
#  3.34,
#  3.14,
#  3.36,
#  3.39,
#  3.3,
#  3.34,
#  3.15,
#  3.42,
#  3.28,
#  3.31,
#  3.37,
#  3.04,
#  3.39,
#  3.37,
#  3.46,
#  3.54,
#  3.37,
#  3.34,
#  3.46,
#  3.32,
#  3.37,
#  3.37,
#  3.37,
#  3.37,
#  3.32,
#  3.0,
#  3.14,
#  3.08,
#  3.07,
#  3.07,
#  3.61,
#  3.38,
#  3.2,
#  3.35,
#  3.61,
#  3.22,
#  3.47,
#  3.17,
#  3.23,
#  3.47,
#  3.26,
#  3.22,
#  3.49,
#  3.06,
#  3.36,
#  3.29,
#  3.35,
#  3.34,
#  3.28,
#  3.08,
#  3.2,
#  3.6,
#  3.35,
#  3.69,
#  3.28,
#  3.36,
#  3.28,
#  3.22,
#  3.31,
#  3.38,
#  3.36,
#  3.69,
#  3.28,
#  3.23,
#  3.38,
#  3.12,
#  3.25,
#  3.36,
#  3.38,
#  3.31,
#  3.31,
#  3.1,
#  3.37,
#  3.34,
#  3.2,
#  3.34,
#  3.3,
#  3.22,
#  3.41,
#  3.05,
#  3.05,
#  3.16,
#  3.67,
#  3.67,
#  3.68,
#  3.38,
#  3.22,
#  3.51,
#  3.39,
#  3.2,
#  3.12,
#  3.36,
#  3.19,
#  3.19,
#  3.41,
#  3.12,
#  3.27,
#  3.32,
#  3.3,
#  3.39,
#  3.42,
#  3.3,
#  3.3,
#  3.37,
#  3.3,
#  3.37,
#  3.24,
#  3.29,
#  3.28,
#  3.16,
#  3.16,
#  3.05,
#  3.28,
#  3.16,
#  3.18,
#  3.23,
#  3.23,
#  3.22,
#  3.13,
#  3.34,
#  3.17,
#  3.35,
#  3.31,
#  3.16,
#  3.11,
#  3.12,
#  3.21,
#  3.3,
#  3.3,
#  3.12,
#  3.6,
#  3.58,
#  3.02,
#  3.11,
#  3.36,
#  3.28,
#  3.35,
#  3.27,
#  3.18,
#  3.25,
#  3.55,
#  3.26,
#  3.24,
#  3.15,
#  3.17,
#  3.19,
#  3.37,
#  3.05,
#  2.99,
#  3.07,
#  3.26,
#  3.07,
#  3.16,
#  3.18,
#  3.2,
#  3.57,
#  3.32,
#  3.32,
#  3.05,
#  3.01,
#  3.01,
#  3.26,
#  3.2,
#  3.11,
#  3.31,
#  3.21,
#  3.06,
#  3.21,
#  3.21,
#  3.42,
#  3.43,
#  3.41,
#  3.31,
#  3.43,
#  3.19,
#  3.56,
#  3.06,
#  3.18,
#  3.16,
#  3.03,
#  3.22,
#  3.47,
#  3.18,
#  3.18,
#  3.1,
#  3.47,
#  3.29,
#  3.1,
#  3.15,
#  3.26,
#  3.36,
#  3.24,
#  3.18,
#  3.19,
#  3.05,
#  3.38,
#  3.38,
#  3.27,
#  3.27,
#  3.26,
#  3.32,
#  3.26,
#  3.44,
#  3.24,
#  3.62,
#  3.28,
#  3.52,
#  3.36,
#  3.15,
#  3.36,
#  3.52,
#  3.49,
#  3.26,
#  3.24,
#  3.1,
#  3.15,
#  3.25,
#  3.0,
#  3.16,
#  3.15,
#  3.16,
#  3.26,
#  3.17,
#  3.15,
#  3.08,
#  2.88,
#  3.06,
#  2.95,
#  3.23,
#  3.57,
#  3.23,
#  3.1,
#  3.22,
#  3.2,
#  3.1,
#  3.1,
#  3.06,
#  3.44,
#  3.26,
#  3.5,
#  3.22,
#  3.37,
#  3.28,
#  3.26,
#  3.25,
#  3.35,
#  3.26,
#  3.18,
#  3.08,
#  2.98,
#  3.48,
#  3.16,
#  3.32,
#  3.17,
#  3.2,
#  3.05,
#  3.2,
#  3.15,
#  3.26,
#  3.2,
#  3.14,
#  3.28,
#  3.18,
#  3.14,
#  3.19,
#  3.12,
#  3.15,
#  3.04,
#  3.04,
#  3.06,
#  3.17,
#  3.17,
#  3.17,
#  3.32,
#  3.34,
#  3.31,
#  3.34,
#  3.32,
#  3.48,
#  3.44,
#  3.15,
#  3.43,
#  3.32,
#  3.15,
#  3.48,
#  3.43,
#  3.17,
#  3.17,
#  3.18,
#  3.21,
#  3.16,
#  3.25,
#  3.17,
#  3.18,
#  3.04,
#  3.02,
#  3.18,
#  3.03,
#  3.09,
#  3.09,
#  3.31,
#  3.25,
#  3.16,
#  3.22,
#  3.36,
#  3.42,
#  3.48,
#  3.38,
#  3.22,
#  3.23,
#  3.24,
#  3.36,
#  3.39,
#  3.34,
#  3.09,
#  3.41,
#  3.16,
#  3.16,
#  3.22,
#  3.28,
#  3.41,
#  3.09,
#  3.37,
#  3.2,
#  3.22,
#  3.26,
#  3.21,
#  3.12,
#  3.06,
#  2.86,
#  3.08,
#  3.45,
#  3.26,
#  3.12,
#  3.27,
#  3.33,
#  3.19,
#  3.12,
#  3.74,
#  2.92,
#  2.92,
#  3.07,
#  2.92,
#  3.07,
#  3.3,
#  3.14,
#  3.23,
#  3.08,
#  3.31,
#  3.3,
#  3.14,
#  3.32,
#  3.32,
#  3.31,
#  3.57,
#  3.32,
#  3.57,
#  3.14,
#  3.3,
#  3.19,
#  3.2,
#  3.34,
#  3.3,
#  3.29,
#  3.14,
#  3.19,
#  3.19,
#  3.19,
#  2.98,
#  3.3,
#  3.47,
#  3.12,
#  3.26,
#  3.72,
#  3.05,
#  3.35,
#  3.12,
#  3.35,
#  3.29,
#  3.4,
#  3.27,
#  3.04,
#  3.09,
#  3.2,
#  3.0,
#  3.26,
#  3.1,
#  3.3,
#  3.1,
#  3.17,
#  3.31,
#  3.34,
#  3.31,
#  3.32,
#  3.56,
#  3.39,
#  2.98,
#  3.32,
#  3.26,
#  2.87,
#  3.5,
#  3.5,
#  3.03,
#  3.13,
#  3.09,
#  3.27,
#  3.28,
#  3.13,
#  3.49,
#  3.46,
#  3.46,
#  3.36,
#  3.36,
#  3.27,
#  3.21,
#  3.27,
#  3.25,
#  3.32,
#  3.43,
#  3.27,
#  3.27,
#  3.24,
#  3.24,
#  3.35,
#  3.18,
#  3.39,
#  3.46,
#  3.39,
#  3.46,
#  3.39,
#  3.37,
#  3.4,
#  3.32,
#  3.33,
#  3.16,
#  2.89,
#  3.41,
#  2.98,
#  3.12,
#  3.08,
#  3.14,
#  2.89,
#  2.92,
#  3.32,
#  3.41,
#  3.32,
#  3.31,
#  3.36,
#  3.04,
#  3.03,
#  3.14,
#  3.18,
#  2.94,
#  3.15,
#  2.94,
#  3.26,
#  3.2,
#  3.15,
#  3.2,
#  3.08,
#  3.26,
#  3.08,
#  3.4,
#  3.48,
#  3.13,
#  3.06,
#  3.21,
#  3.33,
#  3.37,
#  3.25,
#  3.37,
#  3.44,
#  3.28,
#  3.4,
#  3.3,
#  3.63,
#  3.48,
#  3.03,
#  3.32,
#  3.31,
#  3.9,
#  3.47,
#  3.47,
#  3.31,
#  3.11,
#  3.08,
#  3.47,
#  3.47,
#  3.32,
#  3.29,
#  3.37,
#  3.4,
#  3.37,
#  3.34,
#  3.27,
#  3.06,
#  3.38,
#  3.36,
#  3.34,
#  3.28,
#  3.29,
#  3.34,
#  3.21,
#  3.22,
#  3.46,
#  3.22,
#  3.1,
#  3.21,
#  2.94,
#  3.54,
#  3.29,
#  3.43,
#  3.46,
#  3.46,
#  3.61,
#  3.17,
#  3.44,
#  3.39,
#  3.55,
#  3.48,
#  3.26,
#  3.26,
#  3.5,
#  3.1,
#  3.35,
#  3.45,
#  3.21,
#  3.46,
#  3.13,
#  3.13,
#  3.52,
#  3.3,
#  3.3,
#  3.52,
#  3.52,
#  3.29,
#  3.29,
#  3.39,
#  3.29,
#  3.09,
#  3.51,
#  3.6,
#  3.25,
#  3.25,
#  3.19,
#  3.23,
#  3.25,
#  3.31,
#  3.25,
#  3.31,
#  3.31,
#  3.14,
#  3.45,
#  3.55,
#  3.39,
#  3.55,
#  3.28,
#  3.27,
#  3.3,
#  3.31,
#  3.43,
#  3.4,
#  3.4,
#  3.36,
#  3.5,
#  3.31,
#  3.66,
#  3.36,
#  3.66,
#  3.55,
#  3.21,
#  3.21,
#  3.18,
#  3.18,
#  3.09,
#  3.33,
#  3.23,
#  3.48,
#  3.38,
#  3.17,
#  2.99,
#  3.1,
#  3.24,
#  3.29,
#  3.29,
#  3.25,
#  3.23,
#  3.56,
#  3.24,
#  3.26,
#  3.33,
#  3.27,
#  3.33,
#  3.26,
#  3.22,
#  3.3,
#  3.09,
#  3.24,
#  3.44,
#  3.21,
#  3.24,
#  3.23,
#  3.28,
#  3.29,
#  3.28,
#  3.34,
#  3.71,
#  3.61,
#  3.61,
#  3.24,
#  3.36,
#  3.4,
#  3.36,
#  3.46,
#  3.56,
#  3.38,
#  3.56,
#  3.38,
#  3.38,
#  3.32,
#  3.39,
#  3.26,
#  3.26,
#  3.24,
#  3.46,
#  3.24,
#  3.45,
#  3.23,
#  3.28,
#  3.18,
#  3.59,
#  3.59,
#  3.5,
#  3.59,
#  3.58,
#  3.28,
#  3.28,
#  3.22,
#  3.47,
#  3.47,
#  3.51,
#  3.47,
#  3.4,
#  3.15,
#  3.4,
#  3.51,
#  3.66,
#  3.24,
#  3.51,
#  3.51,
#  3.51,
#  3.41,
#  3.4,
#  3.4,
#  3.44,
#  3.41,
#  3.53,
#  3.43,
#  3.23,
#  3.12,
#  3.31,
#  3.4,
#  3.41,
#  3.22,
#  3.53,
#  3.15,
#  3.48,
#  3.22,
#  3.53,
#  3.22,
#  3.34,
#  3.33,
#  3.15,
#  3.43,
#  3.22,
#  3.44,
#  3.53,
#  3.22,
#  3.53,
#  3.53,
#  3.42,
#  3.31,
#  3.42,
#  3.31,
#  3.48,
#  3.4,
#  3.58,
#  3.58,
#  3.41,
#  3.41,
#  3.23,
#  3.39,
#  3.59,
#  3.43,
#  3.29,
#  3.23,
#  3.18,
#  3.33,
#  3.27,
#  3.29,
#  3.27,
#  3.62,
#  3.38,
#  3.3,
#  3.38,
#  3.24,
#  3.3,
#  3.38,
#  3.38,
#  3.18,
#  3.47,
#  3.47,
#  3.2,
#  3.18,
#  3.3,
#  3.69,
#  3.48,
#  3.45,
#  3.48,
#  3.69,
#  3.39,
#  3.39,
#  3.07,
#  3.34,
#  3.61,
#  3.36,
#  3.19,
#  3.22,
#  3.24,
#  3.27,
#  3.14,
#  3.29,
#  3.26,
#  3.41,
#  3.41,
#  3.41,
#  3.26,
#  3.31,
#  3.2,
#  3.44,
#  3.36,
#  3.31,
#  3.29,
#  3.47,
#  3.36,
#  3.16,
#  3.27,
#  3.38,
#  3.15,
#  3.16,
#  3.34,
#  3.13,
#  3.13,
#  3.2,
#  3.46,
#  3.33,
#  3.33,
#  3.22,
#  3.52,
#  3.3,
#  3.44,
#  3.44,
#  3.15,
#  3.28,
#  3.13,
#  3.32,
#  3.25,
#  3.34,
#  3.32,
#  3.13,
#  3.45,
#  3.19,
#  3.44,
#  3.16,
#  3.14,
#  3.16,
#  3.45,
#  3.36,
#  3.45,
#  3.15,
#  3.39,
#  3.71,
#  3.71,
#  3.12,
#  3.47,
#  ...]

# %% [markdown]
# ### What level of acidity receives the highest average rating?

# %%
# View the min, 25%, 50%, 75%, max pH values with Pandas describe
df.describe().pH
bins = [2.72, 3.11, 3.21,3.32,4.01]

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [2.72, 3.11, 3.21,3.32,4.01] # Fill in this list with five values you just found

# %%
# Labels for the four acidity level groups
bin_names = ['High','Moderately High','Medium','Low' ] # Name each acidity level category

# %%
# Creates acidity_levels column
df['acidity_levels'] = pd.cut(df['pH'], bin_edges, labels=bin_names)

# Checks for successful creation of this column
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color   acidity_levels
# 0      9.4        5   red              Low
# 1      9.8        5   red  Moderately High
# 2      9.8        5   red           Medium
# 3      9.8        6   red  Moderately High
# 4      9.4        5   red              Low

# %%
# Find the mean quality of each acidity level with groupby
df.groupby(['quality', 'acidity_levels']).mean()
# Out:
#                          fixed_acidity  volatile_acidity  citric_acid  \
# quality acidity_levels
# 3       High                  9.157143          0.367143     0.361429
#         Moderately High       8.075000          0.365000     0.372500
#         Medium                7.837500          0.553125     0.296250
#         Low                   6.954545          0.641364     0.185455
# 4       High                  7.825758          0.361439     0.378485
#         Moderately High       7.217073          0.418415     0.279024
#         Medium                7.176596          0.457340     0.281915
#         Low                   6.850000          0.587339     0.147581
# 5       High                  7.622648          0.329660     0.388972
#         Moderately High       7.384729          0.357980     0.328407
#         Medium                7.246926          0.409355     0.278566
#         Low                   6.971092          0.483929     0.211349
# 6       High                  7.476579          0.275303     0.363671
#         Moderately High       7.324636          0.291691     0.348601
#         Medium                7.116667          0.318597     0.325142
#         Low                   6.756769          0.373945     0.252737
# 7       High                  7.502642          0.258377     0.356566
#         Moderately High       7.475194          0.286008     0.357752
#         Medium                7.045817          0.295570     0.345970
#         Low                   6.560751          0.312696     0.284744
# 8       High                  7.255556          0.280444     0.333111
#         Moderately High       7.111364          0.286250     0.334091
#         Medium                6.894231          0.268269     0.352308
#         Low                   6.178846          0.326923     0.310962
# 9       High                       NaN               NaN          NaN
#         Moderately High       9.100000          0.270000     0.450000
#         Medium                7.150000          0.300000     0.350000
#         Low                   6.850000          0.310000     0.390000
#
#                          residual_sugar  chlorides  free_sulfur_dioxide  \
# quality acidity_levels
# 3       High                   9.221429   0.073857            36.928571
#         Moderately High        4.337500   0.081750            17.250000
#         Medium                 4.975000   0.079375            36.187500
#         Low                    2.954545   0.075636            50.863636
# 4       High                   5.028030   0.059712            22.121212
#         Moderately High        4.741463   0.051683            27.475610
#         Medium                 3.865957   0.054936            16.819149
#         Low                    3.052419   0.069839            17.427419
# 5       High                   7.501829   0.065510            33.822300
#         Moderately High        6.105255   0.061890            33.587849
#         Medium                 5.415676   0.063689            28.864754
#         Low                    3.730621   0.068270            22.896146
# 6       High                   7.026842   0.051672            34.109211
#         Moderately High        6.079082   0.052608            33.527697
#         Medium                 4.735755   0.054623            29.722222
#         Low                    4.206477   0.058009            27.002911
# 7       High                   6.778679   0.043283            31.296226
#         Moderately High        5.193411   0.044702            32.395349
#         Medium                 3.579848   0.046456            28.623574
#         Low                    3.507679   0.046512            29.508532
# 8       High                   7.386667   0.041289            36.022222
#         Moderately High        6.719318   0.045977            35.431818
#         Medium                 4.575000   0.040731            31.346154
#         Low                    3.325962   0.037269            35.673077
# 9       High                        NaN        NaN                  NaN
#         Moderately High       10.600000   0.035000            28.000000
#         Medium                 3.100000   0.024500            42.000000
#         Low                    1.900000   0.026500            27.500000
#
#                          total_sulfur_dioxide   density        pH  sulphates  \
# quality acidity_levels
# 3       High                       173.071429  0.996644  2.957143   0.517143
#         Moderately High            111.750000  0.995325  3.160000   0.472500
#         Medium                     107.687500  0.995501  3.267500   0.458750
#         Low                        103.727273  0.995500  3.477273   0.546364
# 4       High                       113.863636  0.994285  3.027879   0.491667
#         Moderately High            131.890244  0.994660  3.159512   0.500000
#         Medium                      96.638298  0.994940  3.274468   0.488298
#         Low                         78.661290  0.995448  3.463710   0.537419
# 5       High                       139.162892  0.995761  3.032213   0.512021
#         Moderately High            134.892447  0.995621  3.165222   0.506929
#         Medium                     118.366803  0.995921  3.265799   0.535205
#         Low                         82.573876  0.996180  3.438630   0.560278
# 6       High                       127.894737  0.994411  3.028434   0.506145
#         Moderately High            124.051020  0.994540  3.165510   0.503353
#         Medium                     112.850427  0.994321  3.265926   0.537963
#         Low                         95.515284  0.994975  3.430742   0.585531
# 7       High                       120.056604  0.993619  3.028566   0.496906
#         Moderately High            115.389535  0.993176  3.163333   0.536860
#         Medium                      95.380228  0.992518  3.272129   0.569734
#         Low                        103.752560  0.993182  3.425973   0.580922
# 8       High                       120.288889  0.993038  3.015333   0.420889
#         Moderately High            121.840909  0.993212  3.162273   0.486364
#         Medium                     114.153846  0.992503  3.259808   0.564615
#         Low                        114.826923  0.991479  3.418077   0.561731
# 9       High                              NaN       NaN       NaN        NaN
#         Moderately High            124.000000  0.997000  3.200000   0.460000
#         Medium                     129.000000  0.990175  3.280000   0.420000
#         Low                         99.000000  0.989975  3.390000   0.515000
#
#                            alcohol
# quality acidity_levels
# 3       High             10.085714
#         Moderately High  10.000000
#         Medium           10.325000
#         Low              10.295455
# 4       High             10.230303
#         Moderately High   9.931707
#         Medium           10.124468
#         Low              10.333065
# 5       High              9.726713
#         Moderately High   9.768172
#         Medium            9.829331
#         Low              10.073911
# 6       High             10.490307
#         Moderately High  10.496064
#         Medium           10.701140
#         Low              10.671713
# 7       High             11.034340
#         Moderately High  11.463630
#         Medium           11.695184
#         Low              11.358191
# 8       High             11.362222
#         Moderately High  11.550000
#         Medium           11.634615
#         Low              12.105769
# 9       High                   NaN
#         Moderately High  10.400000
#         Medium           12.600000
#         Low              12.650000

# %%
# Save changes for the next section
df.to_csv('winequality_edited.csv', index=False)
